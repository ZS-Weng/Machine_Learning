# %% [markdown]
# # Using DONUT for Document Visual Question Answering (DocVQA) pretrained model
#
#
# 🤗 Transformers and SentencePiece are required

# %% [markdown]
# !pip install transformers[sentencepiece]

# %%
#!pip install transformers[sentencepiece]

# %% [markdown]
# ## Load libraries model and processor

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path
from PIL import Image
import torch
import re

# %%
from transformers import DonutProcessor, VisionEncoderDecoderModel

processor = DonutProcessor.from_pretrained("naver-clova-ix/donut-base-finetuned-docvqa")
model = VisionEncoderDecoderModel.from_pretrained("naver-clova-ix/donut-base-finetuned-docvqa")
# Out:
# C:\Users\wengz\anaconda3\envs\pytorch_env\lib\site-packages\torch\functional.py:478: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  C:\cb\pytorch_1000000000000\work\aten\src\ATen\native\TensorShape.cpp:2895.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]

# %%
def get_answer(folder_path, filename, question, model, processor):

    image = Image.open(folder_path/filename).convert('RGB')

    pixel_values = processor(image, return_tensors="pt").pixel_values
    
    prompt = f"<s_docvqa><s_question>{question}</s_question><s_answer>"
    decoder_input_ids = processor.tokenizer(prompt, add_special_tokens=False, return_tensors="pt")["input_ids"]

    device = "cuda" if torch.cuda.is_available() else "cpu"
    model.to(device)

    outputs = model.generate(pixel_values.to(device),
                               decoder_input_ids=decoder_input_ids.to(device),
                               max_length=model.decoder.config.max_position_embeddings,
                               early_stopping=True,
                               pad_token_id=processor.tokenizer.pad_token_id,
                               eos_token_id=processor.tokenizer.eos_token_id,
                               use_cache=True,
                               num_beams=3,
                               bad_words_ids=[[processor.tokenizer.unk_token_id]],
                               return_dict_in_generate=True,
                               output_scores=True)
    
    seq = processor.batch_decode(outputs.sequences)[0]
    seq = seq.replace(processor.tokenizer.eos_token, "").replace(processor.tokenizer.pad_token, "")
    seq = re.sub(r"<.*?>", "", seq, count=1).strip()  # remove first task start token
    
    return processor.token2json(seq), outputs['sequences_scores'].item()*-1

# %%
def show_image(image):
    img = image.resize((600,600))
    img = np.asarray(img)
    plt.figure(figsize=(7,7))
    plt.imshow(img)

# %% [markdown]
# ## Extract images from folder and select image

# %%
image_folder = Path("./Images")

# %%
list_file = []
for file in image_folder.iterdir():
    list_file.append(file.name)

# %%
list_file
# Out:
# ['Comfort Delgro 1 Invoice.jpg',
#  'Comfort Delgro 2 Invoice.jpg',
#  'Easter Challenge poster.png',
#  'F1 2022 poster.png',
#  'handwritten receipt Invoice.jpg',
#  'Jacks Place Invoice.jpg',
#  'Oracle Invoice.png',
#  'SAP Goods Receipt Invoice.png',
#  'Stop and Shop Receipt Invoice.jpeg']

# %% [markdown]
# ## Input Question based on image

# %% [markdown]
# ### Testing on a generic receipt

# %%
filename = 'Stop and Shop Receipt Invoice.jpeg'
image = Image.open(image_folder/filename).convert('RGB')

# %%
show_image(image)

# %%
question = "What is the total or balance?"
answer, score = get_answer(image_folder, filename, question, model, processor)

# %%
print(answer)
print(score)
# Out:
# {'question': 'What is the total or balance?', 'answer': '35.01'}

# %%
question = "What is the title?"
answer, score = get_answer(image_folder, filename, question, model, processor)

# %%
print(answer)
print(score)
# Out:
# {'question': 'What is the title?', 'answer': 'stop & shop'}

# %% [markdown]
# ### Testing on a handwritten receipt

# %%
filename = 'handwritten receipt Invoice.jpg'
image = Image.open(image_folder/filename).convert('RGB')

# %%
show_image(image)

# %%
question = "What is the total or balance?"
answer, score = get_answer(image_folder, filename, question, model, processor)

# %%
print(answer)
print(score)
# Out:
# {'question': 'What is the total or balance?', 'answer': '13 73'}

# %%
question = "What is the title?"
answer, score = get_answer(image_folder, filename, question, model, processor)

# %%
print(answer)
print(score)
# Out:
# {'question': 'What is the title?', 'answer': "williams' book store"}

# %% [markdown]
# ### Testing on Singapore F1 2022 poster

# %%
filename = 'F1 2022 poster.png'
image = Image.open(image_folder/filename).convert('RGB')

# %%
image
# Out:
# <PIL.Image.Image image mode=RGB size=1449x2048>

# %%
question = "What is the Pit Combination price?"
answer, score = get_answer(image_folder, filename, question, model, processor)

# %%
print(answer)
print(score)
# Out:
# {'question': 'What is the Pit Combination price?', 'answer': '$1,088'}

# %%
question = "What is the Stamford Combination price?"
answer, score = get_answer(image_folder, filename, question, model, processor)

# %%
print(answer)
print(score)
# Out:
# {'question': 'What is the ticket price for Stamford Combination?', 'answer': '$798'}

# %% [markdown]
# ## Looping through multiple images to extract information

# %%
image_folder = Path("./Images")

#Creating Plot related details
fig = plt.figure(figsize=(12, 10))
rows = 2
columns = 4

for i,file in enumerate(image_folder.glob('*Invoice*')):
    
    # Adds a subplot at the 1st position
    fig.add_subplot(rows, columns, i+1)

    # showing image
    image = Image.open(image_folder/file.name)
    plt.imshow(image)
    plt.axis('off')

# %%
image_folder = Path("./Images")

questions = ['What is the total or balance?',
             'What is the title at the top?']

details_dict = {'Image File':[],
                'Question':[],
                'Data':[]}



for question in questions:

    for file in image_folder.glob('*Invoice*'):

        answer, score = get_answer(image_folder, filename, question, model, processor)

        details_dict['Image File'].append(file.name)
        details_dict['Question'].append(answer['question'])
        details_dict['Data'].append(answer['answer'])

# %%
df_results = pd.DataFrame(details_dict)

# %%
df_results
# Out:
#                             Image File                       Question  \
# 0         Comfort Delgro 1 Invoice.jpg  What is the total or balance?
# 1         Comfort Delgro 2 Invoice.jpg  What is the total or balance?
# 2      handwritten receipt Invoice.jpg  What is the total or balance?
# 3              Jacks Place Invoice.jpg  What is the total or balance?
# 4                   Oracle Invoice.png  What is the total or balance?
# 5        SAP Goods Receipt Invoice.png  What is the total or balance?
# 6   Stop and Shop Receipt Invoice.jpeg  What is the total or balance?
# 7         Comfort Delgro 1 Invoice.jpg  What is the title at the top?
# 8         Comfort Delgro 2 Invoice.jpg  What is the title at the top?
# 9      handwritten receipt Invoice.jpg  What is the title at the top?
# 10             Jacks Place Invoice.jpg  What is the title at the top?
# 11                  Oracle Invoice.png  What is the title at the top?
# ...

# %%
df_results_pivot = df_results.pivot_table(index='Image File',
                                          columns='Question',
                                          values='Data',
                                          aggfunc=lambda x: ''.join(str(v) for v in x)).reset_index()

# %%
df_results_pivot
# Out:
# Question                          Image File What is the title at the top?  \
# 0               Comfort Delgro 1 Invoice.jpg        comfort transportation
# 1               Comfort Delgro 2 Invoice.jpg        comfort transportation
# 2                    Jacks Place Invoice.jpg                  jack's place
# 3                         Oracle Invoice.png                         orale
# 4              SAP Goods Receipt Invoice.png            goods receipt slip
# 5         Stop and Shop Receipt Invoice.jpeg                   stop & shop
# 6            handwritten receipt Invoice.jpg          williams' book store
#
# Question What is the total or balance?
# 0                                 8.32
# 1                              $ 27.60
# 2                                67.68
# 3                           $13,824.00
# 4                               75,000
# 5                                35.01
# 6                                13 73
